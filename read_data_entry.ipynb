# %%
import pandas as pd

forms = pd.read_json('reference/data_entry_forms.json')

# %%
forms
# Out:
#                                                         multi  \
# Diagnoses    {'Primary': 'primary', 'Secondary': 'secondary'}
# Events                   {'Major': 'major', 'Minor': 'minor'}
# Procedures  {'Surgical': 'surgery', 'Interventional': 'int...
# Medication                                                NaN
# Catheter                                                  NaN
# Echo                                                      NaN
# CPEX                                                      NaN
# Bloods                                                    NaN
#
#                                                        single
# Diagnoses                                                 NaN
# Events                                                    NaN
# Procedures                                                NaN
# Medication  {'Medication': 'medication', 'Dose': 0, 'Frequ...
# Catheter    {'sPaP (mmHg)': 0, 'dPaP (mmHg)': 0, 'mPaP (mm...
# ...
