# %%
from utils.orthanc_utils import *
from utils.db_utils import *

# %%
db = TinyDB(DB_PATH)

studies = fetch_db_studies()

# for study in studies[:4]:
study = studies[1]
df = pd.DataFrame([series.__dict__ for series in study.series_dict.values()])
# sax_dl_df = df[(df['dl_orthanc_id'].notna())]
# sax_dl_df

# %%
df
# Out:
#                               orthanc_series_id  \
# 0  e071a5a6-8fa7ab48-2db2044d-8b7267b5-2e1ba0ab
#
#                                          series_uid  \
# 0  1.2.276.0.7230010.3.1.3.0.6772.1775830478.169643
#
#           series_description         series_type           series_group  \
# 0  Whole-Heart SSFP ORIGINAL  Single Whole-Heart  Single Whole-Heart:00
#
#   series_orientation dl_orthanc_id roundel_orthanc_id
# 0           Sagittal          None               None
