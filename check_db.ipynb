# %%
from utils.plot_utils import *
from utils.db_utils import *
from utils.orthanc_utils import *
import re
import pandas as pd

# %%
db = TinyDB(DB_PATH)

studies = fetch_db_studies()

df = pd.DataFrame([series.__dict__ for series in studies[0].series_dict.values()])

df
# Out:
#                                orthanc_series_id  \
# 0   02d55c32-8e4459de-c99229f2-399c6051-1299ca23
# 1   0980fa03-681913d2-e18d1e51-f4483387-51b3a0b2
# 2   1075f377-30023ec5-7a55e918-e243ea19-654c1fbe
# 3   12a8f30b-4de3076d-a755fa4a-cc9c5101-8d849878
# 4   14874921-16aa8154-35280fc4-3cd32688-58d13fbf
# ..                                           ...
# 62  f15a1265-57883f17-ff136437-ef7dcb76-983db9b1
# 63  f99a07e3-b81b844a-5cb4b6d8-788f3928-7a858665
# 64  fc99bdab-57cae910-a44d46f8-7cc02a79-130c468d
# 65  fedfa717-4964c306-a1e84137-0ee86136-59c893e5
# 66  ff433dbd-20a1527f-7723858b-1e2085cb-111ddf1f
#
#                                            series_uid  \
# 0   1.3.12.2.1107.5.2.18.42363.2025080311034669931...
# 1   1.3.12.2.1107.5.2.18.42363.2025080310502741444...
# 2   1.3.12.2.1107.5.2.18.42363.2025080310462140534...
# 3   1.3.12.2.1107.5.2.18.42363.2025080311010184572...
# 4   1.3.12.2.1107.5.2.18.42363.2025080311041523458...
# ...
